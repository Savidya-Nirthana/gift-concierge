# %%
import sys
from pathlib import Path


project_root = Path.cwd().parent
sys.path.insert(0, str(project_root / "src"))

# %%
from services.ingest_service.pipeline import load_markdown_docs
from infrastructure.db.qdrant_client import delete_collection

delete_collection()
# Out:
# 2026-04-11 00:07:26.137 | INFO     | infrastructure.db.qdrant_client:get_qdrant_client:50 - Conntect to Qdrant cloud at https://95e8db76-61bb-4619-9da3-e9a4a2232693.us-west-1-0.aws.cloud.qdrant.io
# 2026-04-11 00:07:27.864 | INFO     | infrastructure.db.qdrant_client:delete_collection:101 - Delete Qdrant collection kapruka

# %%
docs = load_markdown_docs()
# Out:
# 2026-04-09 12:58:52.705 | INFO     | services.ingest_service.pipeline:load_markdown_docs:92 - Loaded 10000 markdown documents from d:\ai\bootcamp\mini-project-03\gift-concierge\data\kapruka_markdowns

# %%
docs
# Out:
# [{'url': 'https://kapruka.com/000_buyonline_mount-lavinia-avurudu-kevili-c_kid_cakemlh00103',
#   'title': '# Send Mount Lavinia Avurudu Kevili C Price in Sri Lanka | At Kapruka',
# ...
